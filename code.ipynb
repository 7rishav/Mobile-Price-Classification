# %% [markdown]
# # AIM:
# In this Project,on the basis of the mobile Specification like Battery power, 3G enabled , wifi ,Bluetooth, Ram etc we are predicting Price range of the mobile

# %% [markdown]
# # Features:
# battery_power:Total energy a battery can store in one time measured in mAh
#
# blue:Has bluetooth or not
#
# clock_speed:speed at which microprocessor executes instructions
#
#
# dual_sim:Has dual sim support or not
#
#
# fc:Front Camera mega pixels
#
#
# four_g:Has 4G or not
#
#
# int_memory:Internal Memory in Gigabytes
#
#
# m_dep:Mobile Depth in cm
#
#
# mobile_wt:Weight of mobile phone
#
#
# n_cores:Number of cores of processor
#
#
# pc:Primary Camera mega pixels
#
#
# px_height:Pixel Resolution Height
#
#
# px_width:Pixel Resolution Width
#
#
# ram:Random Access Memory in Megabytes
#
#
# sc_h:Screen Height of mobile in cm
#
#
# sc_w:Screen Width of mobile in cm
#
#
# talk_time:longest time that a single battery charge will last when you are
#
# three_g:Has 3G or not
#
#
# touch_screen:Has touch screen or not
#
#
# wifi:Has wifi or not
#
# price_range:This is the target variable with value of 0(low cost), 1(medium cost), 2(high cost) and 3(very high cost).

# %% [markdown]
# # Importing libraries and retrieving Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('mobile_price_train.csv')
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   140.249000     4.520500
# std       0.499662    18.145715     0.288416    35.399655     2.287837
# ...

# %% [markdown]
#  We didn't try to detect the outliers here, as we will be training our data on Support Vector Classifier model, and SVC handles the outliers very well.

# %% [markdown]
# # Exploratory Data Analysis

# %%
(df['price_range'].value_counts()).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# From here we can observe that each price range has exactly equall number of mobiles

# %%
corr=df.corr()
plt.figure(figsize = (14,10))
sns.heatmap(corr,cmap='Oranges')
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we cans see here that price range is strongly related to ram, i.e size of ram potentially tells us what will be the prize range
#
# Also if the mobile's height is increased, the width of mobile is also increased, and vice-versa.

# %%
corr.sort_values(by=['price_range'],ascending=False).iloc[0].sort_values(ascending=False)
# Out:
# price_range      1.000000
# ram              0.917046
# battery_power    0.200723
# px_width         0.165818
# px_height        0.148858
# int_memory       0.044435
# sc_w             0.038711
# pc               0.033599
# three_g          0.023611
# sc_h             0.022986
# fc               0.021998
# talk_time        0.021859
# blue             0.020573
# wifi             0.018785
# dual_sim         0.017444
# four_g           0.014772
# n_cores          0.004399
# m_dep            0.000853
# clock_speed     -0.006606
# mobile_wt       -0.030302
# touch_screen    -0.030411
# Name: price_range, dtype: float64

# %%
sns.jointplot(df['ram'],df['price_range'],color='blue',kind='hist')

# %% [markdown]
# We can observe from the above graph that:
#
# 1. The ram for price_range 0 varies from 0 to 2000
# 2. The ram for price_range 1 varies from 0 to 2800
# 3. The ram for price_range 2 varies from 1200 to 4000
# 4. The ram for price_range 3 varies from 2000 to 4000

# %%
sns.jointplot(x=df['int_memory'],y=df['price_range'],kind='kde')

# %% [markdown]
# The above jointplot gives us the information that the each price range has mobiles with variety of all range of internal memory, although the distribution of internal memory is different in each price range

# %%
sns.jointplot(df['battery_power'],df['price_range'],kind='kde')

# %% [markdown]
# As the above jointplot displays, the more is the price_range, the more are the chances that the mobile has more battery_power

# %%
sns.jointplot(df['mobile_wt'],df['price_range'],kind='kde')

# %% [markdown]
# The above jointplot gives the following information:
#
# 1. The mobiles in price range of 3 are more light in weight in comparision to others.
# 2. The mobiles in price range of 2 usually have more weight than others.
# 3. The mobiles in price range of 0 and 1 are have average weight.

# %%
labels=['3G supported','3G not supported']
values=df['three_g'].value_counts().values

plt.pie(values,labels=labels,autopct='%1.2f%%',radius=1.5,startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d8dfbf4f10>,
# ...
#  [Text(-1.1238221478014114, -1.2081075200953857, '3G supported'),
#   Text(1.1238221478014114, 1.2081075200953857, '3G not supported')],
#  [Text(-0.6129938988007698, -0.6589677382338467, '76.15%'),
#   Text(0.6129938988007698, 0.6589677382338466, '23.85%')])

# %%
labels=['4G supported','4G not supported']
values=df['four_g'].value_counts().values

plt.pie(values,labels=labels,autopct='%1.2f%%',radius=1.5,startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d8dfc38ac0>,
# ...
#  [Text(-1.6462375984170647, -0.1113632325231956, '4G supported'),
#   Text(1.646237598417065, 0.1113632325231954, '4G not supported')],
#  [Text(-0.8979477809547625, -0.0607435813762885, '52.15%'),
#   Text(0.8979477809547625, 0.06074358137628839, '47.85%')])

# %% [markdown]
# The above two pie charts show that 76.15% of the mobiles support 3G, but only 52.15% support 4 g

# %% [markdown]
# # Model training and accuracy

# %%
x=df.drop('price_range',axis = 1)
y=df['price_range']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVC
clf = SVC()
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.965

# %%
from sklearn.metrics import confusion_matrix
matrix=confusion_matrix(y_test,y_pred)
print(matrix)
# Out:
# [[103   2   0   0]
#  [  1  90   0   0]
#  [  0   3  87   2]
#  [  0   0   6 106]]

# %%
sns.heatmap(matrix,annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred,labels=[0,1,2,3]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       105
#            1       0.95      0.99      0.97        91
#            2       0.94      0.95      0.94        92
#            3       0.98      0.95      0.96       112
#
#     accuracy                           0.96       400
#    macro avg       0.96      0.97      0.96       400
# weighted avg       0.97      0.96      0.97       400

# %% [markdown]
# # Predicting the price_range on test data

# %%
test= pd.read_csv('mobile_price_test.csv')

# %%
test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193        3  16        226      1412  3476    12     7
# 1    0.8        191        5  12        746       857  3895     6     0
# 2    0.9        186        3   4       1270      1366  2396    17    10
# 3    0.5         96        8  20        295      1752  3893    10     0
# 4    0.5        108        6  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
test.shape
# Out:
# (1000, 21)

# %%
test.columns
# Out:
# Index(['id', 'battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc',
#        'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %%
x_test = test.drop('id',axis=1)

# %%
test['price_range']=clf.predict(x_test)

# %%
test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193        3  16        226      1412  3476    12     7
# 1    0.8        191        5  12        746       857  3895     6     0
# 2    0.9        186        3   4       1270      1366  2396    17    10
# 3    0.5         96        8  20        295      1752  3893    10     0
# 4    0.5        108        6  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
test.to_csv('test_output.csv')
